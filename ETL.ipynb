# %%
import pandas as pd 
from config import username, password, username_heroku, password_heroku, database_heroku, host_heroku, gkey
from sqlalchemy import create_engine

# %%
df = pd.read_csv("Assets/Data/usa_power_plant_database.csv")
df
# Out:
#         id country              country_long  \
# 0        1     USA  United States of America
# 1        2     USA  United States of America
# 2        3     USA  United States of America
# 3        4     USA  United States of America
# 4        5     USA  United States of America
# ...    ...     ...                       ...
# 8685  8686     USA  United States of America
# 8686  8687     USA  United States of America
# 8687  8688     USA  United States of America
# 8688  8689     USA  United States of America
# 8689  8690     USA  United States of America
#
#                                       name   gppd_idnr  capacity_mw  latitude  \
# 0                   12 Applegate Solar LLC  USA0059371          1.9   40.2003
# 1                      126 Grove Solar LLC  USA0060858          2.0   42.0761
# 2                          1420 Coil Av #C  USA0057310          1.3   33.7943
# 3                       145 Talmadge Solar  USA0057458          3.8   40.5358
# 4                        1515 S Caron Road  USA0007770          4.2   41.9084
# ...                                    ...         ...          ...       ...
# 8685                    Zion Energy Center  USA0055392        596.7   42.4776
# 8686  Zion Landfill Gas to Energy Facility  USA0056871          7.0   42.4803
# 8687                                  Zorn  USA0001368         18.0   38.2803
# 8688              Zotos International WPGF  USA0057648          3.4   42.8869
# 8689                   eBay - South Jordan  USA0059281          9.8   40.5606
#
#       longitude primary_fuel other_fuel1  ...  \
# 0      -74.5761        Solar         NaN  ...
# 1      -71.4227        Solar         NaN  ...
# 2     -118.2414        Solar         NaN  ...
# 3      -74.3913        Solar         NaN  ...
# 4      -89.0466          Gas         NaN  ...
# ...         ...          ...         ...  ...
# 8685   -87.8950          Gas         Oil  ...
# 8686   -87.8861        Waste         NaN  ...
# 8687   -85.7023          Gas         NaN  ...
# 8688   -76.9683         Wind         NaN  ...
# 8689  -112.0478          Gas         NaN  ...
#
#                                                url  \
# 0     http://www.eia.gov/electricity/data/browser/
# 1     http://www.eia.gov/electricity/data/browser/
# 2     http://www.eia.gov/electricity/data/browser/
# 3     http://www.eia.gov/electricity/data/browser/
# 4     http://www.eia.gov/electricity/data/browser/
# ...                                            ...
# 8685  http://www.eia.gov/electricity/data/browser/
# 8686  http://www.eia.gov/electricity/data/browser/
# 8687  http://www.eia.gov/electricity/data/browser/
# 8688  http://www.eia.gov/electricity/data/browser/
# 8689  http://www.eia.gov/electricity/data/browser/
#
#                           geolocation_source  wepp_id year_of_capacity_data  \
# 0     U.S. Energy Information Administration      NaN                2017.0
# 1     U.S. Energy Information Administration      NaN                2017.0
# 2     U.S. Energy Information Administration      NaN                2017.0
# 3     U.S. Energy Information Administration  67644.0                2017.0
# 4     U.S. Energy Information Administration  52308.0                2017.0
# ...                                      ...      ...                   ...
# 8685  U.S. Energy Information Administration  49140.0                2017.0
# 8686  U.S. Energy Information Administration  50113.0                2017.0
# 8687  U.S. Energy Information Administration  25154.0                2017.0
# 8688  U.S. Energy Information Administration      NaN                2017.0
# 8689  U.S. Energy Information Administration      NaN                2017.0
#
#      generation_gwh_2013 generation_gwh_2014 generation_gwh_2015  \
# 0                2.41461             2.35000            2.430000
# 1                    NaN                 NaN                 NaN
# 2                1.52800             2.14900            1.515000
# 3                5.03600             4.52400            4.802000
# 4                0.21500             0.17800            0.271000
# ...                  ...                 ...                 ...
# 8685             0.00000            63.65600          132.434005
# 8686            43.59200            49.13400           46.699000
# 8687             0.20300             0.07800            1.058000
# 8688             3.67100             2.46015            2.489000
# 8689            12.96800            51.27600           71.505000
#
#       generation_gwh_2016  generation_gwh_2017  estimated_generation_gwh
# 0                2.492000              2.27600                       NaN
# 1                2.416000              2.25100                  0.891855
# 2                1.592000              1.66000                       NaN
# 3                5.051000              4.81900                       NaN
# 4                0.306000              0.26400                       NaN
# ...                   ...                  ...                       ...
# 8685           435.493999            462.06300                       NaN
# 8686            42.480000             38.66900                       NaN
# 8687             0.062000              0.01500                       NaN
# 8688             1.670000              1.23349                       NaN
# 8689            76.392000             76.63100                       NaN
#
# [8690 rows x 25 columns]

# %%
del df["other_fuel1"]
del df["other_fuel2"]
del df["other_fuel3"]

# %%
del df["estimated_generation_gwh"]
del df["generation_gwh_2013"]
del df["generation_gwh_2014"]
del df["generation_gwh_2015"]
del df["generation_gwh_2016"]

# %%
for column in df:
    nullVal = df[column].isnull().sum()
    print(f"{column}: {nullVal} // {round(nullVal / len(df) *100,2)}")
# Out:
# id: 0 // 0.0
# country: 0 // 0.0
# country_long: 0 // 0.0
# name: 0 // 0.0
# gppd_idnr: 0 // 0.0
# capacity_mw: 0 // 0.0
# latitude: 0 // 0.0
# longitude: 0 // 0.0
# primary_fuel: 0 // 0.0
# commissioning_year: 21 // 0.24
# owner: 13 // 0.15
# source: 0 // 0.0
# url: 0 // 0.0
# geolocation_source: 0 // 0.0
# wepp_id: 3468 // 39.91
# year_of_capacity_data: 42 // 0.48
# generation_gwh_2017: 151 // 1.74

# %%
fuel_types = df["primary_fuel"].unique()
fuel_types
# Out:
# array(['Solar', 'Gas', 'Oil', 'Hydro', 'Wind', 'Coal', 'Biomass', 'Waste',
#        'Cogeneration', 'Storage', 'Geothermal', 'Nuclear', 'Petcoke',
#        'Other'], dtype=object)

# %%
for fuel in fuel_types:
    new_df = df.loc[df['primary_fuel'] == fuel]
    avg = new_df["generation_gwh_2017"].mean()
    print(f"{fuel}: {round(avg,3)}")
    df['generation_gwh_2017'] = df['generation_gwh_2017'].fillna(avg)
# Out:
# Solar: 23.422
# Gas: 749.45
# Oil: 23.506
# Hydro: 201.838
# Wind: 243.609
# Coal: 3548.375
# Biomass: 174.993
# Waste: 83.634
# Cogeneration: 114.993
# Storage: 0.909
# Geothermal: 244.7
# Nuclear: 13359.418
# Petcoke: 694.029
# Other: 102.487

# %%
df["owner"] = df["owner"].fillna("Not listed")
df["commissioning_year"] = df["commissioning_year"].fillna(0)
df["year_of_capacity_data"] = 2017
df["wepp_id"] = df["wepp_id"].fillna(0)

# %%
for column in df:
    nullVal = df[column].isnull().sum()
    print(f"{column}: {nullVal} // {round(nullVal / len(df) *100,2)}%")
# Out:
# id: 0 // 0.0%
# country: 0 // 0.0%
# country_long: 0 // 0.0%
# name: 0 // 0.0%
# gppd_idnr: 0 // 0.0%
# capacity_mw: 0 // 0.0%
# latitude: 0 // 0.0%
# longitude: 0 // 0.0%
# primary_fuel: 0 // 0.0%
# commissioning_year: 0 // 0.0%
# owner: 0 // 0.0%
# source: 0 // 0.0%
# url: 0 // 0.0%
# geolocation_source: 0 // 0.0%
# wepp_id: 0 // 0.0%
# year_of_capacity_data: 0 // 0.0%
# generation_gwh_2017: 0 // 0.0%

# %%
df['commissioning_year'] = df['commissioning_year'].astype(int)

# %%
df.set_index("id",inplace=True)

# %%
# We could not get the df to sql  to work with the heroku db so we used the csv file we just created 
# from the data manipulation and loaded that directly into our postgres db
# df.to_csv("Assets/Data/clean_USA_power_plant_data.csv")

# %%
df["state"] = ""

# %%
df
# Out:
#      country              country_long                                  name  \
# id
# 1        USA  United States of America                12 Applegate Solar LLC
# 2        USA  United States of America                   126 Grove Solar LLC
# 3        USA  United States of America                       1420 Coil Av #C
# 4        USA  United States of America                    145 Talmadge Solar
# 5        USA  United States of America                     1515 S Caron Road
# ...      ...                       ...                                   ...
# 8686     USA  United States of America                    Zion Energy Center
# 8687     USA  United States of America  Zion Landfill Gas to Energy Facility
# 8688     USA  United States of America                                  Zorn
# 8689     USA  United States of America              Zotos International WPGF
# 8690     USA  United States of America                   eBay - South Jordan
#
#        gppd_idnr  capacity_mw  latitude  longitude primary_fuel  \
# id
# 1     USA0059371          1.9   40.2003   -74.5761        Solar
# 2     USA0060858          2.0   42.0761   -71.4227        Solar
# 3     USA0057310          1.3   33.7943  -118.2414        Solar
# 4     USA0057458          3.8   40.5358   -74.3913        Solar
# 5     USA0007770          4.2   41.9084   -89.0466          Gas
# ...          ...          ...       ...        ...          ...
# 8686  USA0055392        596.7   42.4776   -87.8950          Gas
# 8687  USA0056871          7.0   42.4803   -87.8861        Waste
# 8688  USA0001368         18.0   38.2803   -85.7023          Gas
# 8689  USA0057648          3.4   42.8869   -76.9683         Wind
# 8690  USA0059281          9.8   40.5606  -112.0478          Gas
#
#       commissioning_year                         owner  \
# id
# 1                   2012              SunRay Power LLC
# 2                   2012           126 Grove Solar LLC
# 3                   2011               Konoike Pacific
# 4                   2011       Avidan Energy Solutions
# 5                   2000  Rochelle Municipal Utilities
# ...                  ...                           ...
# 8686                2002               Zion Energy LLC
# 8687                2003       Energy Developments Inc
# 8688                1969  Louisville Gas & Electric Co
# 8689                2012           Zotos International
# 8690                2013                  Bloom Energy
#
#                                       source  \
# id
# 1     U.S. Energy Information Administration
# 2     U.S. Energy Information Administration
# 3     U.S. Energy Information Administration
# 4     U.S. Energy Information Administration
# 5     U.S. Energy Information Administration
# ...                                      ...
# 8686  U.S. Energy Information Administration
# 8687  U.S. Energy Information Administration
# 8688  U.S. Energy Information Administration
# 8689  U.S. Energy Information Administration
# 8690  U.S. Energy Information Administration
#
#                                                url  \
# id
# 1     http://www.eia.gov/electricity/data/browser/
# 2     http://www.eia.gov/electricity/data/browser/
# 3     http://www.eia.gov/electricity/data/browser/
# 4     http://www.eia.gov/electricity/data/browser/
# 5     http://www.eia.gov/electricity/data/browser/
# ...                                            ...
# 8686  http://www.eia.gov/electricity/data/browser/
# 8687  http://www.eia.gov/electricity/data/browser/
# 8688  http://www.eia.gov/electricity/data/browser/
# 8689  http://www.eia.gov/electricity/data/browser/
# 8690  http://www.eia.gov/electricity/data/browser/
#
#                           geolocation_source  wepp_id  year_of_capacity_data  \
# id
# 1     U.S. Energy Information Administration      0.0                   2017
# 2     U.S. Energy Information Administration      0.0                   2017
# 3     U.S. Energy Information Administration      0.0                   2017
# 4     U.S. Energy Information Administration  67644.0                   2017
# 5     U.S. Energy Information Administration  52308.0                   2017
# ...                                      ...      ...                    ...
# 8686  U.S. Energy Information Administration  49140.0                   2017
# 8687  U.S. Energy Information Administration  50113.0                   2017
# 8688  U.S. Energy Information Administration  25154.0                   2017
# 8689  U.S. Energy Information Administration      0.0                   2017
# 8690  U.S. Energy Information Administration      0.0                   2017
#
#       generation_gwh_2017 state
# id
# 1                 2.27600
# 2                 2.25100
# 3                 1.66000
# 4                 4.81900
# 5                 0.26400
# ...                   ...   ...
# 8686            462.06300
# 8687             38.66900
# 8688              0.01500
# 8689              1.23349
# 8690             76.63100
#
# [8690 rows x 17 columns]

# %%
import reverse_geocoder as rg 
import pprint

# %%
def reverseGeocode(lat, lng):
    return (lat, lng)

# %%
for index, row in df.iterrows():
    lat = row['latitude']
    lng = row['longitude']
    
    coordinates = reverseGeocode(lat,lng)
    response = rg.search(coordinates)
    state = response[0]['admin1']
    
    df.loc[index, 'state'] = state

# %%
df
# Out:
#      country              country_long                                  name  \
# id
# 1        USA  United States of America                12 Applegate Solar LLC
# 2        USA  United States of America                   126 Grove Solar LLC
# 3        USA  United States of America                       1420 Coil Av #C
# 4        USA  United States of America                    145 Talmadge Solar
# 5        USA  United States of America                     1515 S Caron Road
# ...      ...                       ...                                   ...
# 8686     USA  United States of America                    Zion Energy Center
# 8687     USA  United States of America  Zion Landfill Gas to Energy Facility
# 8688     USA  United States of America                                  Zorn
# 8689     USA  United States of America              Zotos International WPGF
# 8690     USA  United States of America                   eBay - South Jordan
#
#        gppd_idnr  capacity_mw  latitude  longitude primary_fuel  \
# id
# 1     USA0059371          1.9   40.2003   -74.5761        Solar
# 2     USA0060858          2.0   42.0761   -71.4227        Solar
# 3     USA0057310          1.3   33.7943  -118.2414        Solar
# 4     USA0057458          3.8   40.5358   -74.3913        Solar
# 5     USA0007770          4.2   41.9084   -89.0466          Gas
# ...          ...          ...       ...        ...          ...
# 8686  USA0055392        596.7   42.4776   -87.8950          Gas
# 8687  USA0056871          7.0   42.4803   -87.8861        Waste
# 8688  USA0001368         18.0   38.2803   -85.7023          Gas
# 8689  USA0057648          3.4   42.8869   -76.9683         Wind
# 8690  USA0059281          9.8   40.5606  -112.0478          Gas
#
#       commissioning_year                         owner  \
# id
# 1                   2012              SunRay Power LLC
# 2                   2012           126 Grove Solar LLC
# 3                   2011               Konoike Pacific
# 4                   2011       Avidan Energy Solutions
# 5                   2000  Rochelle Municipal Utilities
# ...                  ...                           ...
# 8686                2002               Zion Energy LLC
# 8687                2003       Energy Developments Inc
# 8688                1969  Louisville Gas & Electric Co
# 8689                2012           Zotos International
# 8690                2013                  Bloom Energy
#
#                                       source  \
# id
# 1     U.S. Energy Information Administration
# 2     U.S. Energy Information Administration
# 3     U.S. Energy Information Administration
# 4     U.S. Energy Information Administration
# 5     U.S. Energy Information Administration
# ...                                      ...
# 8686  U.S. Energy Information Administration
# 8687  U.S. Energy Information Administration
# 8688  U.S. Energy Information Administration
# 8689  U.S. Energy Information Administration
# 8690  U.S. Energy Information Administration
#
#                                                url  \
# id
# 1     http://www.eia.gov/electricity/data/browser/
# 2     http://www.eia.gov/electricity/data/browser/
# 3     http://www.eia.gov/electricity/data/browser/
# 4     http://www.eia.gov/electricity/data/browser/
# 5     http://www.eia.gov/electricity/data/browser/
# ...                                            ...
# 8686  http://www.eia.gov/electricity/data/browser/
# 8687  http://www.eia.gov/electricity/data/browser/
# 8688  http://www.eia.gov/electricity/data/browser/
# 8689  http://www.eia.gov/electricity/data/browser/
# 8690  http://www.eia.gov/electricity/data/browser/
#
#                           geolocation_source  wepp_id  year_of_capacity_data  \
# id
# 1     U.S. Energy Information Administration      0.0                   2017
# 2     U.S. Energy Information Administration      0.0                   2017
# 3     U.S. Energy Information Administration      0.0                   2017
# 4     U.S. Energy Information Administration  67644.0                   2017
# 5     U.S. Energy Information Administration  52308.0                   2017
# ...                                      ...      ...                    ...
# 8686  U.S. Energy Information Administration  49140.0                   2017
# 8687  U.S. Energy Information Administration  50113.0                   2017
# 8688  U.S. Energy Information Administration  25154.0                   2017
# 8689  U.S. Energy Information Administration      0.0                   2017
# 8690  U.S. Energy Information Administration      0.0                   2017
#
#       generation_gwh_2017          state
# id
# 1                 2.27600     New Jersey
# 2                 2.25100  Massachusetts
# 3                 1.66000     California
# 4                 4.81900     New Jersey
# 5                 0.26400       Illinois
# ...                   ...            ...
# 8686            462.06300       Illinois
# 8687             38.66900       Illinois
# 8688              0.01500        Indiana
# 8689              1.23349       New York
# 8690             76.63100           Utah
#
# [8690 rows x 17 columns]

# %%
# df.to_csv("Assets/Data/clean_USA_power_plant_data_states.csv")
